# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # <유방암 분류 이미지>
#
# ## [배경]
#
# Context
# According to the WHO, breast cancer is the most commonly occurring cancer worldwide. In 2020 alone, there were 2.3 million new breast cancer diagnoses and 685,000 deaths. Yet breast cancer mortality in high-income countries has dropped by 40% since the 1980s when health authorities implemented regular mammography screening in age groups considered at risk. Early detection and treatment are critical to reducing cancer fatalities, and your machine learning skills could help streamline the process radiologists use to evaluate screening mammograms.
#
# Currently, early detection of breast cancer requires the expertise of highly-trained human observers, making screening mammography programs expensive to conduct. A looming shortage of radiologists in several countries will likely worsen this problem. Mammography screening also leads to a high incidence of false positive results. This can result in unnecessary anxiety, inconvenient follow-up care, extra imaging tests, and sometimes a need for tissue sampling (often a needle biopsy).
#
# The competition host, the Radiological Society of North America (RSNA) is a non-profit organization that represents 31 radiologic subspecialties from 145 countries around the world. RSNA promotes excellence in patient care and health care delivery through education, research, and technological innovation.
#
# Your efforts in this competition could help extend the benefits of early detection to a broader population. Greater access could further reduce breast cancer mortality worldwide.

# %% [markdown]
# # [Dataset Info.]
#
# ### 1. train.csv [파일]
#
#
# ### 2. test.csv [파일]
#
#
# ### 3. sample_submission.csv [제출양식]
#
#
# ### 결론

# %% [markdown]
# 데이터를 확인한 결과는 다음과 같습니다.

# %% [markdown]
# # 1. Data Load & Data library Load

# %% [markdown]
# data_info에서 떠오르는 생각 & 도메인

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install pydicom
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting pydicom
#   Downloading pydicom-2.3.1-py3-none-any.whl (2.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 34.5 MB/s eta 0:00:00
# Installing collected packages: pydicom
# Successfully installed pydicom-2.3.1

# %%
# 데이터분석 세트
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib as mpl

# plt.rcParams['font.family'] = 'Malgun Gothic'
# plt.rcParams['font.family'] = 'NanumGothic'
plt.rc("font", family="Malgun Gothic")
plt.rc('font', family='NanumBarunGothic') 

import warnings
warnings.filterwarnings('ignore')

# %%
# 유방암 데이터 불러오기
base_path = "/content/drive/MyDrive/Colab Notebooks/유방암 이미지 분류_프로젝트/"

train_df = pd.read_csv(base_path + "train_cancer.csv")
test_df = pd.read_csv(base_path + "test_cancer.csv")
# submission = pd.read_csv(base_path + "sample_submission.csv")
# data_info = pd.read_csv(base_path + "data_info.csv")

# %% [markdown]
# # EDA

# %%
print("train.csv 내용")
display(train_df.head())
# Out:
# train.csv 내용
#    site_id  patient_id    image_id laterality view   age  cancer  biopsy  \
# 0        2       10006   462822612          L   CC  61.0       0       0
# 1        2       10006  1459541791          L  MLO  61.0       0       0
# 2        2       10006  1864590858          R  MLO  61.0       0       0
# 3        2       10006  1874946579          R   CC  61.0       0       0
# 4        2       10011   220375232          L   CC  55.0       0       0
#
#    invasive  BIRADS  implant density  machine_id  difficult_negative_case
# 0         0     NaN        0     NaN          29                    False
# 1         0     NaN        0     NaN          29                    False
# 2         0     NaN        0     NaN          29                    False
# 3         0     NaN        0     NaN          29                    False
# 4         0     0.0        0     NaN          21                     True

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 54706 entries, 0 to 54705
# Data columns (total 14 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   site_id                  54706 non-null  int64
#  1   patient_id               54706 non-null  int64
#  2   image_id                 54706 non-null  int64
#  3   laterality               54706 non-null  object
#  4   view                     54706 non-null  object
#  5   age                      54669 non-null  float64
#  6   cancer                   54706 non-null  int64
#  7   biopsy                   54706 non-null  int64
#  8   invasive                 54706 non-null  int64
#  9   BIRADS                   26286 non-null  float64
#  10  implant                  54706 non-null  int64
#  11  density                  29470 non-null  object
#  12  machine_id               54706 non-null  int64
#  13  difficult_negative_case  54706 non-null  bool
# dtypes: bool(1), float64(2), int64(8), object(3)
# memory usage: 5.5+ MB

# %%
train_df.describe().T
# Out:
#               count          mean           std      min           25%  \
# site_id     54706.0  1.460407e+00  4.984344e-01      1.0  1.000000e+00
# patient_id  54706.0  3.269887e+04  1.889386e+04      5.0  1.648100e+04
# image_id    54706.0  1.079386e+09  6.183269e+08  68491.0  5.458153e+08
# age         54669.0  5.854393e+01  1.005088e+01     26.0  5.100000e+01
# cancer      54706.0  2.116770e-02  1.439444e-01      0.0  0.000000e+00
# biopsy      54706.0  5.427193e-02  2.265556e-01      0.0  0.000000e+00
# invasive    54706.0  1.495266e-02  1.213645e-01      0.0  0.000000e+00
# BIRADS      26286.0  7.723503e-01  5.900624e-01      0.0  0.000000e+00
# implant     54706.0  2.699887e-02  1.620815e-01      0.0  0.000000e+00
# machine_id  54706.0  5.461838e+01  4.478480e+01     21.0  2.900000e+01
#
#                      50%           75%           max
# site_id     1.000000e+00  2.000000e+00  2.000000e+00
# patient_id  3.243200e+04  4.899900e+04  6.553400e+04
# image_id    1.082689e+09  1.613228e+09  2.147472e+09
# age         5.900000e+01  6.600000e+01  8.900000e+01
# cancer      0.000000e+00  0.000000e+00  1.000000e+00
# biopsy      0.000000e+00  0.000000e+00  1.000000e+00
# invasive    0.000000e+00  0.000000e+00  1.000000e+00
# BIRADS      1.000000e+00  1.000000e+00  2.000000e+00
# implant     0.000000e+00  0.000000e+00  1.000000e+00
# machine_id  4.900000e+01  4.900000e+01  2.160000e+02

# %% [markdown]
# 대체적로 이상치는 많지는 않다. 하지만 시각화로 살펴봐야 한다.

# %% [markdown]
# #  EDA : 결측치 설정

# %%
train_df.isna().sum()
# Out:
# site_id                        0
# patient_id                     0
# image_id                       0
# laterality                     0
# view                           0
# age                           37
# cancer                         0
# biopsy                         0
# invasive                       0
# BIRADS                     28420
# implant                        0
# density                    25236
# machine_id                     0
# difficult_negative_case        0
# dtype: int64

# %%
test_df.isna().sum()
# Out:
# site_id          0
# patient_id       0
# image_id         0
# laterality       0
# view             0
# age              0
# implant          0
# machine_id       0
# prediction_id    0
# dtype: int64

# %%
# 중간값 찾기

age_median_list = list(set(train_df["age"].to_list()))

def finding(x):

    n=len(x)
    
    if n%2==1:
        result=x[int((n-1)/2)]

    else:
        result=(x[int(n/2)-1]+x[int(n/2)])/2

    return result

result = finding(age_median_list)

print(f"median : {int(result)}")
# Out:
# median : 60

# %%
train_df["age"] = train_df["age"].fillna(0)

# %%
train_df["BIRADS"] = train_df["BIRADS"].fillna(3)

# %%
train_df["density"] = train_df["density"].fillna("E")

# %%
train_df.isnull().sum()
# Out:
# site_id                    0
# patient_id                 0
# image_id                   0
# laterality                 0
# view                       0
# age                        0
# cancer                     0
# biopsy                     0
# invasive                   0
# BIRADS                     0
# implant                    0
# density                    0
# machine_id                 0
# difficult_negative_case    0
# dtype: int64

# %% [markdown]
# 결측치 처리 됨.
#
# 1. age : 0으로 설정
#
# 2.  BIRADS : 3 으로 채운다. : 이유는 검사를 안한 경우.
#
# 3. density :  E:  유방 보정물을 넣은 사람 또는 유방이 없는 사람??
#
# 분석한 데이터를 가지고

# %% [markdown]
# # EDA: 데이터 중복확인

# %%
# train 데이터 중복확인 
train_df_drop_dup = list(train_df.columns)
train_df.drop_duplicates(subset= train_df_drop_dup)
# Out:
#        site_id  patient_id    image_id laterality view   age  cancer  biopsy  \
# 0            2       10006   462822612          L   CC  61.0       0       0
# 1            2       10006  1459541791          L  MLO  61.0       0       0
# 2            2       10006  1864590858          R  MLO  61.0       0       0
# 3            2       10006  1874946579          R   CC  61.0       0       0
# 4            2       10011   220375232          L   CC  55.0       0       0
# ...        ...         ...         ...        ...  ...   ...     ...     ...
# 54701        1        9973  1729524723          R  MLO  43.0       0       0
# 54702        1        9989    63473691          L  MLO  60.0       0       0
# 54703        1        9989  1078943060          L   CC  60.0       0       0
# 54704        1        9989   398038886          R  MLO  60.0       0       0
# 54705        1        9989   439796429          R   CC  60.0       0       0
#
#        invasive  BIRADS  implant density  machine_id  difficult_negative_case
# 0             0     3.0        0       E          29                    False
# 1             0     3.0        0       E          29                    False
# 2             0     3.0        0       E          29                    False
# 3             0     3.0        0       E          29                    False
# 4             0     0.0        0       E          21                     True
# ...         ...     ...      ...     ...         ...                      ...
# 54701         0     1.0        0       C          49                    False
# 54702         0     3.0        0       C         216                    False
# 54703         0     3.0        0       C         216                    False
# 54704         0     0.0        0       C         216                     True
# 54705         0     0.0        0       C         216                     True
#
# [54706 rows x 14 columns]

# %% [markdown]
# 중복은 없는 것으로 판단됨.

# %% [markdown]
# # 데이터 종류 및 수 확인

# %%
 # 데이터에 고유값들이 어떠한 종류들이 있는지 알고 싶을때 사용하는 함수
def kinds_data(var):
    column_names = var.columns.values.tolist() 

    for i in column_names:
        print(f"{i} = {var[i].unique()}")  # 데이터에 고유값들이 어떠한 종류들이 있는지 알고 싶을때 사용하는 함수

# %%
kinds_data(train_df)
# Out:
# site_id = [2 1]
# patient_id = [10006 10011 10025 ...   997  9973  9989]
# image_id = [ 462822612 1459541791 1864590858 ... 1078943060  398038886  439796429]
# laterality = ['L' 'R']
# view = ['CC' 'MLO' 'ML' 'LM' 'AT' 'LMO']
# age = [61. 55. 75. 60. 51. 62. 52. 67. 53. 38. 44. 40. 57. 56. 71. 58. 46. 76.
#  68. 69. 54. 59. 64. 50. 73. 70. 65. 45. 63. 47. 66. 72. 82. 49. 77. 85.
#  79. 78. 74. 41. 43. 48. 83. 42. 89. 80. 86. 84. 39. 81. 36. 88. 37. 28.
#  87. 32. 35. 34. 26. 30. 31. 33. 29.]
# cancer = [0 1]
# biopsy = [0 1]
# invasive = [0 1]
# BIRADS = [3. 0. 1. 2.]
# implant = [0 1]
# density = ['E' 'C' 'D' 'B' 'A']
# machine_id = [ 29  21 216  93  49  48 170 210 190 197]
# difficult_negative_case = [False  True]

# %%
kinds_data(test_df)
# Out:
# site_id = [2]
# patient_id = [10008]
# image_id = [ 736471439 1591370361   68070693  361203119]
# laterality = ['L' 'R']
# view = ['MLO' 'CC']
# age = [81]
# implant = [0]
# machine_id = [21]
# prediction_id = ['10008_L' '10008_R']

# %%
# nunique()는 데이터에 고유값들의 수를 출력해주는 함수입니다.

def number_data(var):
    column_names = var.columns.values.tolist()   # tolist() 는 리스트로 묶어주는 함수

    # type(column_names)

    print(column_names, "\n"); print(type(column_names))

    for i in column_names:
            print(f"{i} = {var[i].nunique()}")  # nunique()는 데이터에 고유값들의 수를 출력해주는 함수입니다.

# %%
number_data(train_df)
# Out:
# ['site_id', 'patient_id', 'image_id', 'laterality', 'view', 'age', 'cancer', 'biopsy', 'invasive', 'BIRADS', 'implant', 'density', 'machine_id', 'difficult_negative_case']
#
# <class 'list'>
# site_id = 2
# patient_id = 11913
# image_id = 54706
# laterality = 2
# view = 6
# age = 63
# cancer = 2
# biopsy = 2
# invasive = 2
# BIRADS = 4
# implant = 2
# density = 5
# machine_id = 10
# difficult_negative_case = 2

# %%
number_data(test_df)
# Out:
# ['site_id', 'patient_id', 'image_id', 'laterality', 'view', 'age', 'implant', 'machine_id', 'prediction_id']
#
# <class 'list'>
# site_id = 1
# patient_id = 1
# image_id = 4
# laterality = 2
# view = 2
# age = 1
# implant = 1
# machine_id = 1
# prediction_id = 2

# %% [markdown]
# # 시각화로 데이터 분포 살펴보기

# %%
fig, axes = plt.subplots(7, 2, figsize=(30,30))

print(train_df.groupby('site_id').size())
sns.countplot(x='site_id', data=train_df, ax=axes[0][0])
print("-" * 40)
print(train_df.groupby('patient_id').size())
sns.countplot(x='patient_id', data=train_df, ax=axes[0][1])
print("-" * 40)
print(train_df.groupby('image_id').size())
sns.countplot(x='image_id', data=train_df, ax=axes[1][0])
print("-" * 40)
print(train_df.groupby('laterality').size())
sns.countplot(x='laterality', data=train_df, ax=axes[1][1])
print("-" * 40)
print(train_df.groupby('view').size())
sns.countplot(x='view', data=train_df, ax=axes[2][0])
print("-" * 40)
print(train_df.groupby('age').size())
sns.countplot(x='age', data=train_df, ax=axes[2][1])
print("-" * 40)
print(train_df.groupby('cancer').size())
sns.countplot(x='cancer', data=train_df, ax=axes[3][0])
print("-" * 40)
print(train_df.groupby('biopsy').size())
sns.countplot(x='biopsy', data=train_df, ax=axes[3][1])
print("-" * 40)
print(train_df.groupby('invasive').size())
sns.countplot(x='invasive', data=train_df, ax=axes[4][0])
print("-" * 40)
print(train_df.groupby('BIRADS').size())
sns.countplot(x='BIRADS', data=train_df, ax=axes[4][1])
print("-" * 40)
print(train_df.groupby('implant').size())
sns.countplot(x='implant', data=train_df, ax=axes[5][0])
print("-" * 40)
print(train_df.groupby('machine_id').size())
sns.countplot(x='machine_id', data=train_df, ax=axes[5][1])
print("-" * 40)
print(train_df.groupby('difficult_negative_case').size())
sns.countplot(x='difficult_negative_case', data=train_df, ax=axes[6][0])
print("-" * 40)
print(train_df.groupby('density').size())
sns.countplot(x='density', data=train_df, ax=axes[6][1])

plt.tight_layout()
plt.show()
# Out:
# site_id
# 1    29519
# 2    25187
# dtype: int64
# ----------------------------------------
# patient_id
# 5        4
# 25       6
# 28       4
# 30       4
# 33       5
#         ..
# 65518    4
# 65525    4
# 65526    4
# 65530    6
# 65534    4
# Length: 11913, dtype: int64
# ----------------------------------------
# image_id
# 68491         1
# 83977         1
# 127964        1
# 193459        1
# 225973        1
#              ..
# 2147266534    1
# 2147293172    1
# 2147355367    1
# 2147415608    1
# 2147471846    1
# Length: 54706, dtype: int64
# ----------------------------------------
# laterality
# L    27267
# R    27439
# dtype: int64
# ----------------------------------------
# view
# AT        19
# CC     26765
# LM        10
# LMO        1
# ML         8
# MLO    27903
# dtype: int64
# ----------------------------------------
# age
# 0.0     37
# 26.0    11
# 28.0    18
# 29.0     7
# 30.0     5
#         ..
# 85.0    68
# 86.0    78
# 87.0    47
# 88.0    37
# 89.0    70
# Length: 64, dtype: int64
# WARNING:matplotlib.font_manager:findfont: Font family ['NanumBarunGothic'] not found. Falling back to DejaVu Sans.
# ----------------------------------------
# cancer
# 0    53548
# 1     1158
# dtype: int64
# ----------------------------------------
# biopsy
# 0    51737
# 1     2969
# dtype: int64
# ----------------------------------------
# invasive
# 0    53888
# 1      818
# dtype: int64
# ----------------------------------------
# BIRADS
# 0.0     8249
# 1.0    15772
# 2.0     2265
# 3.0    28420
# dtype: int64
# ----------------------------------------
# implant
# 0    53229
# 1     1477
# dtype: int64
# ----------------------------------------
# machine_id
# 21      8221
# 29      8267
# 48      8699
# 49     23529
# 93      1915
# 170      923
# 190      145
# 197       29
# 210     1070
# 216     1908
# dtype: int64
# ----------------------------------------
# difficult_negative_case
# False    47001
# True      7705
# dtype: int64
# ----------------------------------------
# density
# A     3105
# B    12651
# C    12175
# D     1539
# E    25236
# dtype: int64

# %%
print("site_1에서의 환자별 이미지 데이터 갯수: ",
    train_df[train_df['site_id']==1].groupby('patient_id').image_id.count().unique(),
    "\nsite_2에서의 환자별 이미지 데이터 갯수: ",
    train_df[train_df['site_id']==2].groupby('patient_id').image_id.count().unique())
# Out:
# site_1에서의 환자별 이미지 데이터 갯수:  [1 2]
# site_2에서의 환자별 이미지 데이터 갯수:  [1 2]

# %%
print("train image data와 train.csv 내 patient_id는 각각 모두 정보가 있다.")
print("train.csv의 환자 id 갯수: ", train_df.patient_id.nunique()) 
    #   ", train image의 환자 id 갯수: ",len(os.listdir(train_df)))
# Out:
# train image data와 train.csv 내 patient_id는 각각 모두 정보가 있다.
# train.csv의 환자 id 갯수:  28

# %%
# view에서 CC와 MLO 제외한 부분에서의 데이터 갯수를 살펴보기. 
train_df=train_df[train_df.view.isin(['ML','LM','AT','LMO'])]
plt.figure(figsize=(20,20))
sns.countplot(data=train_df, x='view')
plt.show()

# %% [markdown]
# # 두 변수 간 상관 관계도 보기.

# %%
mask = np.zeros_like(train_df.corr())
mask[np.triu_indices_from(mask)] = True
plt.rcParams["figure.figsize"] = (20,20)
sns.heatmap(data = train_df.corr(), mask=mask, annot=True, fmt = '.3f', linewidths=0, cmap='Greens')

# %% [markdown]
# # 상관관계도에서
#                cancer <-> invasive 살펴보니 양성에서 침습성이 크다.
#
#                cancer <-> biopsy
#
#                biopsy <-> invasive
#
#                site_id <-> BIRADS
#
#                biopsy <-> difficult_negative_case

# %%
fig, axes = plt.subplots(7, 2, figsize=(30,30))

sns.countplot(data=train_df, x='site_id', hue='cancer', ax=axes[0][0])
sns.countplot(data=train_df, x='patient_id', hue='cancer', ax=axes[0][1])
sns.countplot(data=train_df, x='image_id', hue='cancer', ax=axes[1][0])
sns.countplot(data=train_df, x='laterality', hue='cancer', ax=axes[1][1])
sns.countplot(data=train_df, x='view', hue='cancer', ax=axes[2][0])
sns.countplot(data=train_df, x='age', hue='cancer', ax=axes[2][1])
sns.countplot(data=train_df, x='biopsy', hue='cancer', ax=axes[3][0])
sns.countplot(data=train_df, x='invasive', hue='cancer', ax=axes[3][1])
sns.countplot(data=train_df, x='BIRADS', hue='cancer', ax=axes[4][0])
sns.countplot(data=train_df, x='implant', hue='cancer', ax=axes[4][1])
sns.countplot(data=train_df, x='density', hue='cancer', ax=axes[5][0])
sns.countplot(data=train_df, x='machine_id', hue='cancer', ax=axes[5][1])
sns.countplot(data=train_df, x='difficult_negative_case', hue='cancer', ax=axes[6][0])

plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(20,20))
sns.histplot(data=train_df, x='age', hue='cancer')
plt.show()

# %%
# 각 열의 비율을 찾는 코드
# cancer의 양성과 음성의 비율을 찾아보기. 
var_rate_info = dict()
# cc_idx=0
# cc_per=0
for i in range(len(train_df.cancer.value_counts())):
    var_idx = train_df.cancer.value_counts().index[i]
    var_per = train_df.cancer.value_counts().values[i]/train_df.cancer.value_counts().values.sum()*100
    var_rate_info[var_idx] = var_per  # 이코드는 딕션어리 문법에서 추가하는 것이다. 위에 var_rate_info = dict() 여기에 모아두는 것이다. 
    
print("cancer의 양/음성 비율은, ", var_rate_info)
# Out:
# cancer의 양/음성 비율은,  {0: 97.8832303586444, 1: 2.11676964135561}

# %%
print(train_df.groupby(['density','invasive']).size().div(100))
plt.figure(figsize=(20,10))
sns.countplot(data=train_df, x='density', hue='invasive', order=["E","B", "C", "A", "D"])
plt.show()
# Out:
# density  invasive
# A        0            30.71
#          1             0.34
# B        0           124.45
#          1             2.06
# C        0           119.77
#          1             1.98
# D        0            15.27
#          1             0.12
# E        0           248.68
#          1             3.68
# dtype: float64

# %%
print(train_df.groupby(['density','implant']).size().div(100))
plt.figure(figsize=(20,10))
sns.countplot(data=train_df, x='density', hue='implant',order=["E","B", "C", "A", "D"])
plt.show()
# Out:
# density  implant
# A        0           30.22
#          1            0.83
# B        0          121.94
#          1            4.57
# C        0          113.19
#          1            8.56
# D        0           14.75
#          1            0.64
# E        0          252.19
#          1            0.17
# dtype: float64

# %%
print(train_df.groupby(['invasive','implant']).size().div(100))
plt.figure(figsize=(20,10))
sns.countplot(data=train_df, x='implant', hue='invasive')
plt.show()
# Out:
# invasive  implant
# 0         0          524.24
#           1           14.64
# 1         0            8.05
#           1            0.13
# dtype: float64

# %%
print(train_df.groupby(['implant','invasive', "density", "cancer"]).size().div(100))
# Out:
# implant  invasive  density  cancer
# 0        0         A        0          29.69
#                             1           0.19
#                    B        0         118.94
#                             1           1.03
#                    C        0         110.46
#                             1           0.79
#                    D        0          14.50
#                             1           0.13
#                    E        0         247.25
#                             1           1.26
#          1         A        1           0.34
#                    B        1           1.97
#                    C        1           1.94
#                    D        1           0.12
#                    E        1           3.68
# 1        0         A        0           0.83
#                    B        0           4.48
#                    C        0           8.52
#                    D        0           0.64
#                    E        0           0.17
#          1         B        1           0.09
#                    C        1           0.04
# dtype: float64

# %%
print(train_df.groupby(['invasive', "density", "cancer"]).size().div(100))
# Out:
# invasive  density  cancer
# 0         A        0          30.52
#                    1           0.19
#           B        0         123.42
#                    1           1.03
#           C        0         118.98
#                    1           0.79
#           D        0          15.14
#                    1           0.13
#           E        0         247.42
#                    1           1.26
# 1         A        1           0.34
#           B        1           2.06
#           C        1           1.98
#           D        1           0.12
#           E        1           3.68
# dtype: float64

# %% [markdown]
# - 픽처 선택할때 implant는 빼자. 두 데이터 비교 분석했을때 큰 영향을 미치지 않음.

# %%
print(train_df.groupby(['biopsy','invasive', "BIRADS", "difficult_negative_case"]).size().div(100))
# Out:
# biopsy  invasive  BIRADS  difficult_negative_case
# 0       0         0.0     True                        58.94
#                   1.0     False                      157.72
#                   2.0     False                       22.65
#                   3.0     False                      278.06
# 1       0         0.0     False                        2.14
#                           True                        16.91
#                   3.0     False                        1.26
#                           True                         1.20
#         1         0.0     False                        4.50
#                   3.0     False                        3.68
# dtype: float64

# %%
train_df["age"].value_counts()
# Out:
# 50.0    2248
# 62.0    2038
# 64.0    2011
# 54.0    2004
# 57.0    1964
#         ...
# 26.0      11
# 33.0      10
# 29.0       7
# 30.0       5
# 31.0       4
# Name: age, Length: 64, dtype: int64

# %%
print(train_df.groupby(['machine_id','cancer']).size().div(100))
plt.figure(figsize=(20,10))
sns.countplot(data=train_df, x='machine_id', hue='cancer')
plt.show()
# Out:
# machine_id  cancer
# 21          0          80.67
#             1           1.54
# 29          0          81.06
#             1           1.61
# 48          0          85.20
#             1           1.79
# 49          0         229.15
#             1           6.14
# 93          0          19.01
#             1           0.14
# 170         0           9.00
#             1           0.23
# 190         0           1.40
#             1           0.05
# 197         0           0.29
# 210         0          10.70
# 216         0          19.00
#             1           0.08
# dtype: float64

# %%
print(train_df.groupby(['implant','cancer']).patient_id.size())
plt.figure(figsize=(20,10))
sns.countplot(data=train_df, x='implant', hue='cancer')
plt.show()
# Out:
# implant  cancer
# 0        0         52084
#          1          1145
# 1        0          1464
#          1            13
# Name: patient_id, dtype: int64

# %%
print("양성인 경우만 0. 지속적인 진료가 필요하다.")
plt.figure(figsize=(20,10))
sns.countplot(data=train_df, x='BIRADS', hue='cancer')
plt.show()
# Out:
# 양성인 경우만 0. 지속적인 진료가 필요하다.

# %%
plt.figure(figsize=(20,10))
sns.countplot(data=train_df, x='density', hue='cancer')
plt.show()

# %%
print("음성인 경우 invasive가 양성으로 나온적은 없다.")
plt.figure(figsize=(20,10))
sns.countplot(data=train_df, x='invasive', hue='cancer', rotation = 180)
plt.show()
# Out:
# 음성인 경우 invasive가 양성으로 나온적은 없다.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-5e068d330add> in <module>
#       1 print("음성인 경우 invasive가 양성으로 나온적은 없다.")
# ----> 2 plt.figure(figsize=(20,10))
#       3 sns.countplot(data=train_df, x='invasive', hue='cancer', rotation = 180)
#       4 plt.show()
#
# NameError: name 'plt' is not defined

# %%
train_df[train_df['cancer']==0]
# Out:
#        site_id  patient_id    image_id laterality view   age  cancer  biopsy  \
# 0            2       10006   462822612          L   CC  61.0       0       0
# 1            2       10006  1459541791          L  MLO  61.0       0       0
# 2            2       10006  1864590858          R  MLO  61.0       0       0
# 3            2       10006  1874946579          R   CC  61.0       0       0
# 4            2       10011   220375232          L   CC  55.0       0       0
# ...        ...         ...         ...        ...  ...   ...     ...     ...
# 54701        1        9973  1729524723          R  MLO  43.0       0       0
# 54702        1        9989    63473691          L  MLO  60.0       0       0
# 54703        1        9989  1078943060          L   CC  60.0       0       0
# 54704        1        9989   398038886          R  MLO  60.0       0       0
# 54705        1        9989   439796429          R   CC  60.0       0       0
#
#        invasive  BIRADS  implant density  machine_id  difficult_negative_case
# 0             0     3.0        0       E          29                    False
# 1             0     3.0        0       E          29                    False
# 2             0     3.0        0       E          29                    False
# 3             0     3.0        0       E          29                    False
# 4             0     0.0        0       E          21                     True
# ...         ...     ...      ...     ...         ...                      ...
# 54701         0     1.0        0       C          49                    False
# 54702         0     3.0        0       C         216                    False
# 54703         0     3.0        0       C         216                    False
# 54704         0     0.0        0       C         216                     True
# 54705         0     0.0        0       C         216                     True
#
# [53548 rows x 14 columns]

# %%
print("cancer이 양성인 경우- invasive인지 아닌지 ")
plt.figure(figsize=(20,10))
sns.countplot(data=train_df[train_df['cancer']==1], x='invasive', color='orange')
plt.show()
# Out:
# cancer이 양성인 경우- invasive인지 아닌지

# %%
# 
print("cancer 양성인 경우, ML, LM, LMO는 존재하지 않았다.")
plt.figure(figsize=(20,10))
sns.countplot(data=train_df[train_df['cancer']==1], x='view')
plt.show()
# Out:
# cancer 양성인 경우, ML, LM, LMO는 존재하지 않았다.

# %%
# 유방암의 음성이 MLO 와 CC에서만 발견이 되었다.  
print("음성인 경우: CC, MLO에서 많이 발견 되었다.")
plt.figure(figsize=(20,10))
sns.countplot(data=train_df[train_df['cancer']==0], x='view')
plt.show()
# Out:
# 음성인 경우: CC, MLO에서 많이 발견 되었다.

# %%
# 유방암의 음성이 MLO 와 CC에서 많이 발견 되었다.  
print(train_df.groupby(['cancer', "view"]).size().sort_values(ascending=False))
plt.figure(figsize=(20,10))
sns.countplot(data=train_df[train_df['cancer']==1], x='view')
plt.show()
# Out:
# cancer  view
# 0       MLO     27313
#         CC      26199
# 1       MLO       590
#         CC        566
# 0       AT         17
#         LM         10
#         ML          8
# 1       AT          2
# 0       LMO         1
# dtype: int64

# %%
# 유방 사진이 오른쪽과 왼쪽의 갯수는 동일함.
print(train_df.groupby(['laterality', "cancer"]).size().sort_values(ascending=False))
plt.figure(figsize=(20,10))
sns.countplot(data=train_df[train_df['cancer']==1], x='laterality')
plt.show()
# Out:
# laterality  cancer
# R           0         26869
# L           0         26679
#             1           588
# R           1           570
# dtype: int64

# %%
# 악성유방암은 나이가 50~69에서 많이 나오지 않는다.
print(train_df.groupby(['invasive', "age"]).size().sort_values(ascending=False))
plt.figure(figsize=(25,20))
sns.countplot(data=train_df[train_df['invasive']==0], x='age')
plt.show()
# Out:
# invasive  age
# 0         50.0    2224
#           62.0    2021
#           54.0    1988
#           64.0    1984
#           57.0    1953
#                   ...
# 1         42.0       2
#           84.0       2
#           44.0       2
#           47.0       2
#           89.0       2
# Length: 113, dtype: int64

# %%
# 악성유방암은 나이가 50~76에서 많이 나온다. 
print(train_df.groupby(['invasive', "age"]).size().sort_values(ascending=False))
plt.figure(figsize=(25,25))
sns.countplot(data=train_df[train_df['invasive']==1], x='age')
plt.show()
# Out:
# invasive  age
# 0         50.0    2224
#           62.0    2021
#           54.0    1988
#           64.0    1984
#           57.0    1953
#                   ...
# 1         42.0       2
#           84.0       2
#           44.0       2
#           47.0       2
#           89.0       2
# Length: 113, dtype: int64

# %%
print(train_df.groupby(['laterality', "view"]).size().div(1000).sort_values(ascending=False))
plt.figure(figsize=(20,10))
sns.countplot(data=train_df[train_df['cancer']==1], x='view')
plt.show()
# Out:
# laterality  view
# L           MLO     13.958
# R           MLO     13.945
#             CC      13.470
# L           CC      13.295
# R           AT       0.012
# L           AT       0.007
# R           LM       0.006
#             ML       0.005
# L           LM       0.004
#             ML       0.003
# R           LMO      0.001
# dtype: float64

# %%
print("암이 음성인 경우 ")
print(train_df[train_df.cancer==0].age.describe())
print("-"*40)
print("암이 양성인 경우 ")
print(train_df[train_df.cancer==1].age.describe())
print("결론","-"*30)
print("cancer가 양성인 경우 median값이 더 높다 (56, 65)")
# Out:
# 암이 음성인 경우
# count    53548.000000
# mean        58.392433
# std         10.136714
# min          0.000000
# 25%         51.000000
# 50%         58.000000
# 75%         66.000000
# max         89.000000
# Name: age, dtype: float64
# ----------------------------------------
# 암이 양성인 경우
# count    1158.000000
# mean       63.678756
# std         9.991980
# min        38.000000
# 25%        56.000000
# 50%        64.500000
# 75%        71.000000
# max        89.000000
# Name: age, dtype: float64
# 결론 ------------------------------
# cancer가 양성인 경우 median값이 더 높다 (56, 65)

# %%
print("density value count")
print(train_df.density.value_counts())
print("-"*40)
print("cancer 양성인 경우 density value count")
print(train_df[train_df['cancer']==1].density.value_counts())
print("-"*40)
print("cancer 음성인 경우 density value count")
print(train_df[train_df['cancer']==0].density.value_counts())
# Out:
# density value count
# E    25236
# B    12651
# C    12175
# A     3105
# D     1539
# Name: density, dtype: int64
# ----------------------------------------
# cancer 양성인 경우 density value count
# E    494
# B    309
# C    277
# A     53
# D     25
# Name: density, dtype: int64
# ----------------------------------------
# cancer 음성인 경우 density value count
# E    24742
# B    12342
# C    11898
# A     3052
# D     1514
# Name: density, dtype: int64

# %%
print(train_df.groupby(["cancer", 'biopsy', "BIRADS"]).size().div(1000).sort_values(ascending=False))
plt.figure(figsize=(20,10))
sns.countplot(data=train_df[train_df['cancer']==0], x='biopsy')
plt.show()
# Out:
# cancer  biopsy  BIRADS
# 0       0       3.0       27.806
#                 1.0       15.772
#                 0.0        5.894
#                 2.0        2.265
#         1       0.0        1.691
# 1       1       0.0        0.664
#                 3.0        0.494
# 0       1       3.0        0.120
# dtype: float64

# %%
print(train_df.groupby(["cancer", 'biopsy', "BIRADS"]).size().div(1000).sort_values(ascending=False))
plt.figure(figsize=(20,10))
sns.countplot(data=train_df[train_df['cancer']==1], x='biopsy')
plt.show()
# Out:
# cancer  biopsy  BIRADS
# 0       0       3.0       27.806
#                 1.0       15.772
#                 0.0        5.894
#                 2.0        2.265
#         1       0.0        1.691
# 1       1       0.0        0.664
#                 3.0        0.494
# 0       1       3.0        0.120
# dtype: float64

# %%
print(train_df.groupby(["cancer", 'biopsy', "BIRADS"]).size().div(1000).sort_values(ascending=False))
plt.figure(figsize=(20,10))
sns.countplot(data=train_df[train_df['cancer']==1], x='BIRADS')
plt.show()
# Out:
# cancer  biopsy  BIRADS
# 0       0       3.0       27.806
#                 1.0       15.772
#                 0.0        5.894
#                 2.0        2.265
#         1       0.0        1.691
# 1       1       0.0        0.664
#                 3.0        0.494
# 0       1       3.0        0.120
# dtype: float64

# %%
print(train_df.groupby(["cancer", 'biopsy', "BIRADS"]).size().div(1000).sort_values(ascending=False))
plt.figure(figsize=(20,10))
sns.countplot(data=train_df[train_df['cancer']==0], x='BIRADS')
plt.show()
# Out:
# WARNING:matplotlib.font_manager:findfont: Font family ['NanumBarunGothic'] not found. Falling back to DejaVu Sans.
# cancer  biopsy  BIRADS
# 0       0       3.0       27.806
#                 1.0       15.772
#                 0.0        5.894
#                 2.0        2.265
#         1       0.0        1.691
# 1       1       0.0        0.664
#                 3.0        0.494
# 0       1       3.0        0.120
# dtype: float64

# %%
print(train_df.groupby(["cancer", 'biopsy']).size().div(1000).sort_values(ascending=False))
plt.figure(figsize=(20,10))
sns.countplot(data=train_df[train_df['cancer']==0], x='biopsy')
plt.show()
# Out:
# WARNING:matplotlib.font_manager:findfont: Font family ['NanumBarunGothic'] not found. Falling back to DejaVu Sans.
# cancer  biopsy
# 0       0         51.737
#         1          1.811
# 1       1          1.158
# dtype: float64

# %%
print(train_df.groupby(["cancer", 'biopsy']).size().sort_values(ascending=False))
plt.figure(figsize=(20,10))
sns.countplot(data=train_df[train_df['cancer']==1], x='biopsy')
plt.show()
# Out:
# cancer  biopsy
# 0       0         51737
#         1          1811
# 1       1          1158
# dtype: int64

# %%
print(train_df.groupby(["cancer", 'BIRADS']).size().sort_values(ascending=False))
plt.figure(figsize=(20,10))
sns.countplot(data=train_df[train_df['cancer']==1], x='BIRADS')
plt.show()
# Out:
# cancer  BIRADS
# 0       3.0       27926
#         1.0       15772
#         0.0        7585
#         2.0        2265
# 1       0.0         664
#         3.0         494
# dtype: int64

# %%
print(train_df.groupby(["cancer", 'BIRADS']).size().sort_values(ascending=False))
plt.figure(figsize=(20,10))
sns.countplot(data=train_df[train_df['cancer']==0], x='BIRADS')
plt.show()
# Out:
# cancer  BIRADS
# 0       3.0       27926
#         1.0       15772
#         0.0        7585
#         2.0        2265
# 1       0.0         664
#         3.0         494
# dtype: int64

# %% [markdown]
# # EDA 결과
#
# 1. 유방암은 50~70대에 빈번히 많이 발생한다.
#
# 2. implant, machine_id, difficult_negative_case는 feature에서 뺀다. 이유는 cancer EDA 하는 과정에 크게 영향이 없다고 데이터 분석에 나옴.
#
# 3. biopsy와 BIRADS만 EDA 하고 바로 feature 작업 및 이미지 모델링으로 진행.
#
# 4. biopsy랑 BIRADS는 유방암분류하는데 기여도 낮다.

# %%
# 분석에서 제외

train_desc = train.describe().transpose()
train_desc[train_desc['std']==0].index
# Out:
# Index(['vehicle_restricted', 'height_restricted'], dtype='object')
